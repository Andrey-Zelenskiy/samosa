# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Helvetica"
})

import matplotlib as mpl

# %%
import sys
from os.path import dirname

sys.path.append(dirname("../src/"))

from samosa.particle.particle_utils import Particle
from samosa.symmetry.point_group_utils import point_group

# %%
test_p_1 = Particle(n_faces = 3)
test_p_1.n_faces, test_p_1.face_coloring
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1344666/2684689739.py in <module>
# ----> 1 test_p_1 = Particle(n_faces = 3)
#       2 test_p_1.n_faces, test_p_1.face_coloring
#
# ~/Documents/samosa/tutorials/../src/samosa/particle/particle_utils.py in __init__(self, particle_symmetry, coloring_symmetry, n_faces, face_coloring)
#      72
#      73         self.particle_symmetry = particle_symmetry
# ---> 74         self.coloring_symmetry = coloring_symmetry
#      75         self.n_faces = n_faces
#      76         self.face_coloring = face_coloring
#
# AttributeError: can't set attribute 'coloring_symmetry'

# %%
test_p_2 = Particle(face_coloring = [0,1,2])
test_p_2.n_faces, test_p_2.face_coloring
# Out:
# Number of particle faces is not set.
# (3, array([0, 1, 2]))

# %%
test_p_3 = Particle(n_faces = 2, face_coloring = [0,1,2])
test_p_3.n_faces, test_p_3.face_coloring
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_1338186/4173205247.py in <module>
# ----> 1 test_p_3 = Particle(n_faces = 2, face_coloring = [0,1,2])
#       2 test_p_3.n_faces, test_p_3.face_coloring
#
# ~/Documents/samosa/tutorials/../src/samosa/particle/particle_utils.py in __init__(self, n_faces, face_coloring)
#      52
#      53         self.n_faces = n_faces
# ---> 54         self.face_coloring = face_coloring
#      55
#      56
#
# ~/Documents/samosa/tutorials/../src/samosa/particle/particle_utils.py in face_coloring(self, val)
#      98
#      99             if not_None(self.n_faces):
# --> 100                 check_len('face_coloring',val,self.n_faces)
#     101             else:
#     102                 self.n_faces = len(val)
#
# ~/Documents/samosa/tutorials/../src/samosa/api/api_utils.py in check_len(var_name, var, var_len)
#      91
# ...

# %%
a = "3"

b = f"{a} is a number"

print(b)
# Out:
# 3 is a number

# %%
test_d.update_list()
test_d.file_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1344963/2313813982.py in <module>
# ----> 1 test_d.update_list()
#       2 test_d.file_list
#
# NameError: name 'test_d' is not defined

# %%
test_pg = point_group('C3v')

# %%
def f(**kwargs):
    print(kwargs['potato'])

f(potato=3), f(tomato=3)
# Out:
# 3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1334152/368975673.py in <module>
#       2     print(kwargs['potato'])
#       3
# ----> 4 f(potato=3), f(tomato=3)
#
# /tmp/ipykernel_1334152/368975673.py in f(**kwargs)
#       1 def f(**kwargs):
# ----> 2     print(kwargs['potato'])
#       3
#       4 f(potato=3), f(tomato=3)
#
# KeyError: 'potato'
