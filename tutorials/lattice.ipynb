# %%
import sys
from os.path import dirname

sys.path.append(dirname("../src/"))

# %%
from samosa.structures import Lattice

# %% [markdown]
# # Index
#
# * [](#)

# %% [markdown]
# # General-purpose database  <a name="general-database"></a>
#
# To simplify the manipulation of input data in samosa, `Database` class defines most necessary methods for analysing and loading available data files.
# Currently, the module is designed to read data from files with _.toml_ extension.

# %%
lattice = Lattice(dimension=2, space_group_index=15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1120355/1078220471.py in <module>
# ----> 1 lattice = Lattice(dimension=2, space_group_index=15)
#
# ~/Documents/samosa/tutorials/../src/samosa/structures/__init__.py in __init__(self, dimension, space_group_index, positions, crystal_parameters)
#     112
#     113         # Group sites into Wyckoff classes
# --> 114         self.__wyckoff_list = Orbit.sort_into_orbits(input_positions,
#     115                                                      self.space_group)
#     116
#
# ~/Documents/samosa/tutorials/../src/samosa/symmetry/group.py in sort_into_orbits(cls, item_list, group)
#     812         while len(item_list) != 0:
#     813             p = item_list[0]
# --> 814             item_orbit = cls.from_group(group, p)
#     815
#     816             for q in item_orbit.points:
#
# ...
