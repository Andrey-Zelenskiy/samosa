# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Helvetica"
})

import matplotlib as mpl

# %%
import sys
from os.path import dirname
sys.path.append(dirname("/home/andrey/Documents/LPTMS/"\
                      + "frusa_symmetry/python/src/"))
import symmetry_utils as symmetry

# %%
class particle:
    """
    Defines an anisotropic particle object.

    A particle is characterized by its topology and geometry.

    Topological propertie:
    - Number of faces;
    - Particle symmetry (if given);
    - Face coloring (if given);

    Geometric properties:
    - Space and particle face point group (determines the generic shape of the
      particle);
    - Spatial coordinates of particle faces;
    - Positions of patches on the particle (if given).
    
    
    """

    def __init__(self, faces, site_symmetry):
        """
        Initialize a particle based on the site and bond point group symmetry.

        Arguments:
        faces         - list, coordinates of particle's faces;
        site_symmetry - 
        """
